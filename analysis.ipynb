# %%
import pandas as pd

# %%
# reading from the file
file = open("agaricus-lepiota.data", "r")
file.read()
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7620\925834871.py in <module>
#       1 # reading from the file
# ----> 2 file = open("agaricus-lepiota.data", "r")
#       3 file.read()
#       4 file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'agaricus-lepiota.data'

# %%
# reading from the file
file = open("agaricus-lepiota.data")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7620\2212214827.py in <module>
#       1 # reading from the file
# ----> 2 file = open("agaricus-lepiota.data")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'agaricus-lepiota.data'

# %%
n=2
thislist = ["apple", "banana", "cherry"]
for x in thislist:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
for x in thislist[n]:
    print(x)
# Out:
# c
# h
# e
# r
# r
# y

# %%
import pandas as pd

# %%
data =pd.read_csv(r"E:\analisys\child-mortality.csv")

# %%
data
# Out:
#             Entity Code  Year  Under-five mortality rate
# 0      Afghanistan  AFG  2014                   7.337743
# 1      Afghanistan  AFG  2015                   7.017226
# 2      Afghanistan  AFG  2016                   6.724831
# 3      Afghanistan  AFG  2017                   6.458192
# 4      Afghanistan  AFG  2018                   6.217177
# ...            ...  ...   ...                        ...
# 16734     Zimbabwe  ZWE  2009                   9.125017
# 16735     Zimbabwe  ZWE  2010                   8.610624
# 16736     Zimbabwe  ZWE  2011                   8.058766
# 16737     Zimbabwe  ZWE  2012                   7.214632
# 16738     Zimbabwe  ZWE  2013                   6.622255
#
# [16739 rows x 4 columns]

# %%
bb=data.drop(data.columns[[1,3,5,6,7,8,9,-2]], axis=1,inplace=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7620\3683156315.py in <module>
# ----> 1 bb=data.drop(data.columns[[1,3,5,6,7,8,9,-2]], axis=1,inplace=False)
#
# NameError: name 'data' is not defined

# %%
bb.to_csv("jakanaka",index=False)

# %%
bb
# Out:
#        39   77516   13   2174   0   40   <=50K
# 0      50   83311   13      0   0   13   <=50K
# 1      38  215646    9      0   0   40   <=50K
# 2      53  234721    7      0   0   40   <=50K
# 3      28  338409   13      0   0   40   <=50K
# 4      37  284582   14      0   0   40   <=50K
# ...    ..     ...  ...    ...  ..  ...     ...
# 32555  27  257302   12      0   0   38   <=50K
# 32556  40  154374    9      0   0   40    >50K
# 32557  58  151910    9      0   0   40   <=50K
# 32558  22  201490    9      0   0   20   <=50K
# 32559  52  287927    9  15024   0   40    >50K
#
# [32560 rows x 7 columns]

# %%
data.describe()
# Out:
#                  39         77516            13          2174             0  \
# count  32560.000000  3.256000e+04  32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05     10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05      2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#                  40
# count  32560.000000
# mean      40.437469
# std       12.347618
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %%
data .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   39              32560 non-null  int64
#  1    State-gov      32560 non-null  object
#  2    77516          32560 non-null  int64
#  3    Bachelors      32560 non-null  object
#  4    13             32560 non-null  int64
#  5    Never-married  32560 non-null  object
#  6    Adm-clerical   32560 non-null  object
#  7    Not-in-family  32560 non-null  object
#  8    White          32560 non-null  object
#  9    Male           32560 non-null  object
#  10   2174           32560 non-null  int64
#  11   0              32560 non-null  int64
#  12   40             32560 non-null  int64
#  13   United-States  32560 non-null  object
#  14   <=50K          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data .columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10656\2743283449.py in <module>
# ----> 1 data .columns
#
# NameError: name 'data' is not defined

# %%
d=pd.read_csv(r'E:\adult.test')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24528\2294572896.py in <module>
# ----> 1 d=pd.read_csv(r'E:\adult.test')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
d.head(10)
# Out:
#                                                                                                                                            |1x3 Cross validator
# 25  Private          226802  11th         7   Never-married       Machine-op-inspct  Own-child      Black  Male   0    0 40  United-States               <=50K.
# 38  Private          89814   HS-grad      9   Married-civ-spouse  Farming-fishing    Husband        White  Male   0    0 50  United-States               <=50K.
# 28  Local-gov        336951  Assoc-acdm   12  Married-civ-spouse  Protective-serv    Husband        White  Male   0    0 40  United-States                >50K.
# 44  Private          160323  Some-college 10  Married-civ-spouse  Machine-op-inspct  Husband        Black  Male   7688 0 40  United-States                >50K.
# 18  ?                103497  Some-college 10  Never-married       ?                  Own-child      White  Female 0    0 30  United-States               <=50K.
# ...

# %%
d.describe()
# Out:
#        |1x3 Cross validator
# count                 16281
# unique                    2
# top                  <=50K.
# freq                  12435

# %%
df=pd.concat((data,d))

# %%
df.
# Out:
#                                                       39          State-gov  \
# 0                                                   50.0   Self-emp-not-inc
# 1                                                   38.0            Private
# 2                                                   53.0            Private
# 3                                                   28.0            Private
# 4                                                   37.0            Private
# ...                                                  ...                ...
# (39,  Private, 215419,  Bachelors, 13,  Divorce...   NaN                NaN
# (64,  ?, 321403,  HS-grad, 9,  Widowed,  ?,  Ot...   NaN                NaN
# (38,  Private, 374983,  Bachelors, 13,  Married...   NaN                NaN
# (44,  Private, 83891,  Bachelors, 13,  Divorced...   NaN                NaN
# (35,  Self-emp-inc, 182148,  Bachelors, 13,  Ma...   NaN                NaN
#
# ...

# %%
from glob import glob

# %%
file=glob('log*')

# %%
file
# Out:
# []

# %%
df.tail()
# Out:
#                                                     39  State-gov   77516  \
# (39,  Private, 215419,  Bachelors, 13,  Divorce... NaN        NaN     NaN
# (64,  ?, 321403,  HS-grad, 9,  Widowed,  ?,  Ot... NaN        NaN     NaN
# (38,  Private, 374983,  Bachelors, 13,  Married... NaN        NaN     NaN
# (44,  Private, 83891,  Bachelors, 13,  Divorced... NaN        NaN     NaN
# (35,  Self-emp-inc, 182148,  Bachelors, 13,  Ma... NaN        NaN     NaN
#
#                                                     Bachelors   13  \
# (39,  Private, 215419,  Bachelors, 13,  Divorce...        NaN  NaN
# (64,  ?, 321403,  HS-grad, 9,  Widowed,  ?,  Ot...        NaN  NaN
# (38,  Private, 374983,  Bachelors, 13,  Married...        NaN  NaN
# (44,  Private, 83891,  Bachelors, 13,  Divorced...        NaN  NaN
# (35,  Self-emp-inc, 182148,  Bachelors, 13,  Ma...        NaN  NaN
#
#                                                     Never-married  \
# ...

# %%
d
# Out:
#                                                                                                                                                      |1x3 Cross validator
# 25  Private      226802  11th         7   Never-married       Machine-op-inspct  Own-child       Black               Male   0    0 40  United-States               <=50K.
# 38  Private      89814   HS-grad      9   Married-civ-spouse  Farming-fishing    Husband         White               Male   0    0 50  United-States               <=50K.
# 28  Local-gov    336951  Assoc-acdm   12  Married-civ-spouse  Protective-serv    Husband         White               Male   0    0 40  United-States                >50K.
# 44  Private      160323  Some-college 10  Married-civ-spouse  Machine-op-inspct  Husband         Black               Male   7688 0 40  United-States                >50K.
# ...

# %%
d.columns
# Out:
# Index(['|1x3 Cross validator'], dtype='object')

# %%
16290/15
# Out:
# 1086.0

# %%
d.shape
# Out:
# (16281, 1)

# %%
d.reshape(1086,15)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13192\3274155953.py in <module>
# ----> 1 d.reshape(1086,15)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'

# %%
d
# Out:
#                                                                                                                                                      |1x3 Cross validator
# 25  Private      226802  11th         7   Never-married       Machine-op-inspct  Own-child       Black               Male   0    0 40  United-States               <=50K.
# 38  Private      89814   HS-grad      9   Married-civ-spouse  Farming-fishing    Husband         White               Male   0    0 50  United-States               <=50K.
# 28  Local-gov    336951  Assoc-acdm   12  Married-civ-spouse  Protective-serv    Husband         White               Male   0    0 40  United-States                >50K.
# 44  Private      160323  Some-college 10  Married-civ-spouse  Machine-op-inspct  Husband         Black               Male   7688 0 40  United-States                >50K.
# ...

# %%
d.index
# Out:
# MultiIndex([(25,          ' Private', 226802,         ' 11th',  7, ...),
#             (38,          ' Private',  89814,      ' HS-grad',  9, ...),
#             (28,        ' Local-gov', 336951,   ' Assoc-acdm', 12, ...),
#             (44,          ' Private', 160323, ' Some-college', 10, ...),
#             (18,                ' ?', 103497, ' Some-college', 10, ...),
#             (34,          ' Private', 198693,         ' 10th',  6, ...),
#             (29,                ' ?', 227026,      ' HS-grad',  9, ...),
#             (63, ' Self-emp-not-inc', 104626,  ' Prof-school', 15, ...),
#             (24,          ' Private', 369667, ' Some-college', 10, ...),
#             (55,          ' Private', 104996,      ' 7th-8th',  4, ...),
#             ...
#             (61,          ' Private',  89686,      ' HS-grad',  9, ...),
#             (31,          ' Private', 440129,      ' HS-grad',  9, ...),
#             (25,          ' Private', 350977,      ' HS-grad',  9, ...),
# ...

# %%
df[d].str.split(",",expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13192\408024355.py in <module>
# ----> 1 df[d].str.split(",",expand=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3490         # Do we have a (boolean) DataFrame?
#    3491         if isinstance(key, DataFrame):
# -> 3492             return self.where(key)
#    3493
#    3494         # Do we have a (boolean) 1d indexer?
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#   10962         try_cast=lib.no_default,
# ...

# %%
d
# Out:
#                                                                                                                                                      |1x3 Cross validator
# 25  Private      226802  11th         7   Never-married       Machine-op-inspct  Own-child       Black               Male   0    0 40  United-States               <=50K.
# 38  Private      89814   HS-grad      9   Married-civ-spouse  Farming-fishing    Husband         White               Male   0    0 50  United-States               <=50K.
# 28  Local-gov    336951  Assoc-acdm   12  Married-civ-spouse  Protective-serv    Husband         White               Male   0    0 40  United-States                >50K.
# 44  Private      160323  Some-college 10  Married-civ-spouse  Machine-op-inspct  Husband         Black               Male   7688 0 40  United-States                >50K.
# ...

# %%
d=pd.read_csv(r"E:\analisys\adult.test")

# %%
dj=pd.DataFrame(d)

# %%
dj
# Out:
#        age      workclass   fnlwgt      education   education-num  \
# 0       25        Private   226802           11th               7
# 1       38        Private    89814        HS-grad               9
# 2       28      Local-gov   336951     Assoc-acdm              12
# 3       44        Private   160323   Some-college              10
# 4       18              ?   103497   Some-college              10
# ...    ...            ...      ...            ...             ...
# 16276   39        Private   215419      Bachelors              13
# 16277   64              ?   321403        HS-grad               9
# 16278   38        Private   374983      Bachelors              13
# 16279   44        Private    83891      Bachelors              13
# 16280   35   Self-emp-inc   182148      Bachelors              13
#
#             marital-status          occupation     relationship  \
# 0            Never-married   Machine-op-inspct        Own-child
# ...

# %%
file =open (r"E:\analisys\adult.txt")

# %%
file
# Out:
# <_io.TextIOWrapper name='E:\\analisys\\adult.txt' mode='r' encoding='cp1252'>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13192\2333595118.py in <module>
# ----> 1 file.str.split(",")
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'str'

# %%
import pandas as pd

# %%
dt=pd.read_csv(r"E:\analisys\adult.txt")

# %%
dt
# Out:
#        age          workclass   fnlwgt    education   education-num  \
# 0       39          State-gov    77516    Bachelors              13
# 1       50   Self-emp-not-inc    83311    Bachelors              13
# 2       38            Private   215646      HS-grad               9
# 3       53            Private   234721         11th               7
# 4       28            Private   338409    Bachelors              13
# ...    ...                ...      ...          ...             ...
# 32556   27            Private   257302   Assoc-acdm              12
# 32557   40            Private   154374      HS-grad               9
# 32558   58            Private   151910      HS-grad               9
# 32559   22            Private   201490      HS-grad               9
# 32560   52       Self-emp-inc   287927      HS-grad               9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
dt["age"].mean()
# Out:
# 38.58164675532078

# %%
dt["age"].sum()/dt["age"].count()
# Out:
# 38.58164675532078

# %%
dt.columns
# Out:
# Index(['age', ' workclass', ' fnlwgt', ' education', ' education-num',
#        ' marital-status', ' occupation', ' relationship', ' race', ' sex',
#        ' capital-gain', ' capital-loss', ' hours-per-week', ' native-country',
#        ' weights'],
#       dtype='object')

# %%
df3 = dt.groupby([' marital-status'])[[' sex','age',' race',' weights']].mean().reset_index()

# %%
df3
# Out:
#            marital-status        age
# 0                Divorced  43.041639
# 1       Married-AF-spouse  32.478261
# 2      Married-civ-spouse  43.247596
# 3   Married-spouse-absent  40.578947
# 4           Never-married  28.150988
# 5               Separated  39.354146
# 6                 Widowed  58.975831

# %%
ll=dt.loc[0:7," workclass":" sex"]
ll
# Out:
#            workclass   fnlwgt   education   education-num  \
# 0          State-gov    77516   Bachelors              13
# 1   Self-emp-not-inc    83311   Bachelors              13
# 2            Private   215646     HS-grad               9
# 3            Private   234721        11th               7
# 4            Private   338409   Bachelors              13
# 5            Private   284582     Masters              14
# 6            Private   160187         9th               5
# 7   Self-emp-not-inc   209642     HS-grad               9
#
#            marital-status          occupation    relationship    race      sex
# 0           Never-married        Adm-clerical   Not-in-family   White     Male
# 1      Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2                Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3      Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# ...

# %%
dt
# Out:
#        age          workclass   fnlwgt    education   education-num  \
# 0       39          State-gov    77516    Bachelors              13
# 1       50   Self-emp-not-inc    83311    Bachelors              13
# 2       38            Private   215646      HS-grad               9
# 3       53            Private   234721         11th               7
# 4       28            Private   338409    Bachelors              13
# ...    ...                ...      ...          ...             ...
# 32556   27            Private   257302   Assoc-acdm              12
# 32557   40            Private   154374      HS-grad               9
# 32558   58            Private   151910      HS-grad               9
# 32559   22            Private   201490      HS-grad               9
# 32560   52       Self-emp-inc   287927      HS-grad               9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
ll
# Out:
#            workclass   fnlwgt   education   education-num  \
# 0          State-gov    77516   Bachelors              13
# 1   Self-emp-not-inc    83311   Bachelors              13
# 2            Private   215646     HS-grad               9
# 3            Private   234721        11th               7
# 4            Private   338409   Bachelors              13
# 5            Private   284582     Masters              14
# 6            Private   160187         9th               5
# 7   Self-emp-not-inc   209642     HS-grad               9
#
#            marital-status          occupation    relationship    race      sex
# 0           Never-married        Adm-clerical   Not-in-family   White     Male
# 1      Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2                Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3      Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# ...

# %%
ll.drop([' education-num',' fnlwgt'],axis=1)
# Out:
#            workclass   education          marital-status          occupation  \
# 0          State-gov   Bachelors           Never-married        Adm-clerical
# 1   Self-emp-not-inc   Bachelors      Married-civ-spouse     Exec-managerial
# 2            Private     HS-grad                Divorced   Handlers-cleaners
# 3            Private        11th      Married-civ-spouse   Handlers-cleaners
# 4            Private   Bachelors      Married-civ-spouse      Prof-specialty
# 5            Private     Masters      Married-civ-spouse     Exec-managerial
# 6            Private         9th   Married-spouse-absent       Other-service
# 7   Self-emp-not-inc     HS-grad      Married-civ-spouse     Exec-managerial
#
#      relationship    race      sex
# 0   Not-in-family   White     Male
# 1         Husband   White     Male
# 2   Not-in-family   White     Male
# 3         Husband   Black     Male
# 4            Wife   Black   Female
# 5            Wife   White   Female
# ...

# %%
ll[' sex']
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4     Female
# 5     Female
# 6     Female
# 7       Male
# Name:  sex, dtype: object

# %%
ll[ll[' education-num']==13]
# Out:
#            workclass   fnlwgt   education   education-num  \
# 0          State-gov    77516   Bachelors              13
# 1   Self-emp-not-inc    83311   Bachelors              13
# 4            Private   338409   Bachelors              13
#
#         marital-status        occupation    relationship    race      sex
# 0        Never-married      Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White     Male
# 4   Married-civ-spouse    Prof-specialty            Wife   Black   Female

# %%
ll[' sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
ll[ll[' sex']==" Male"]
# Out:
#            workclass   fnlwgt   education   education-num  \
# 0          State-gov    77516   Bachelors              13
# 1   Self-emp-not-inc    83311   Bachelors              13
# 2            Private   215646     HS-grad               9
# 3            Private   234721        11th               7
# 7   Self-emp-not-inc   209642     HS-grad               9
#
#         marital-status          occupation    relationship    race    sex
# 0        Never-married        Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
# 7   Married-civ-spouse     Exec-managerial         Husband   White   Male

# %%
d
# Out:
#        age      workclass   fnlwgt      education   education-num  \
# 0       25        Private   226802           11th               7
# 1       38        Private    89814        HS-grad               9
# 2       28      Local-gov   336951     Assoc-acdm              12
# 3       44        Private   160323   Some-college              10
# 4       18              ?   103497   Some-college              10
# ...    ...            ...      ...            ...             ...
# 16276   39        Private   215419      Bachelors              13
# 16277   64              ?   321403        HS-grad               9
# 16278   38        Private   374983      Bachelors              13
# 16279   44        Private    83891      Bachelors              13
# 16280   35   Self-emp-inc   182148      Bachelors              13
#
#             marital-status          occupation     relationship  \
# 0            Never-married   Machine-op-inspct        Own-child
# ...

# %%
da=pd.concat((dt,d))

# %%
da.head(10)
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
# 5   37            Private   284582     Masters              14
# 6   49            Private   160187         9th               5
# 7   52   Self-emp-not-inc   209642     HS-grad               9
# 8   31            Private    45781     Masters              14
# 9   42            Private   159449   Bachelors              13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
dt.groupby([' marital-status'])[[' sex','age',' race',' weights']].mean().reset_index()

# %%
dj=da.groupby([' weights'])[[' sex',' race',' native-country']].sum().reset_index()

# %%
dj
# Out:
#    weights                                                sex  \
# 0    <=50K   Male Male Male Male Female Female Female Fema...
# 1   <=50K.   Male Male Female Male Male Female Male Male F...
# 2     >50K   Male Female Male Male Male Male Female Male M...
# 3    >50K.   Male Male Male Male Male Male Male Male Male ...
#
#                                                 race  \
# 0   White White White Black Black White Black Whi...
# 1   Black White White White Black White White Whi...
# 2   White White White Black Asian-Pac-Islander As...
# 3   White Black White White White White Asian-Pac...
#
#                                       native-country
# 0   United-States United-States United-States Uni...
# 1   United-States United-States United-States Uni...
# 2   United-States United-States United-States Uni...
# 3   United-States United-States United-States Uni...

# %%
dt
# Out:
#        age          workclass   fnlwgt    education   education-num  \
# 0       39          State-gov    77516    Bachelors              13
# 1       50   Self-emp-not-inc    83311    Bachelors              13
# 2       38            Private   215646      HS-grad               9
# 3       53            Private   234721         11th               7
# 4       28            Private   338409    Bachelors              13
# ...    ...                ...      ...          ...             ...
# 32556   27            Private   257302   Assoc-acdm              12
# 32557   40            Private   154374      HS-grad               9
# 32558   58            Private   151910      HS-grad               9
# 32559   22            Private   201490      HS-grad               9
# 32560   52       Self-emp-inc   287927      HS-grad               9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
import pandas as pd

# %%
d=pd.read_csv(r'E:\\adult.test')

# %%
d
# Out:
#        age      workclass   fnlwgt      education   education-num  \
# 0       25        Private   226802           11th               7
# 1       38        Private    89814        HS-grad               9
# 2       28      Local-gov   336951     Assoc-acdm              12
# 3       44        Private   160323   Some-college              10
# 4       18              ?   103497   Some-college              10
# ...    ...            ...      ...            ...             ...
# 16276   39        Private   215419      Bachelors              13
# 16277   64              ?   321403        HS-grad               9
# 16278   38        Private   374983      Bachelors              13
# 16279   44        Private    83891      Bachelors              13
# 16280   35   Self-emp-inc   182148      Bachelors              13
#
#             marital-status          occupation     relationship  \
# 0            Never-married   Machine-op-inspct        Own-child
# ...

# %%
dt=pd.read_csv(r"E:\adult.txt")

# %%
dt
# Out:
#        age          workclass   fnlwgt    education   education-num  \
# 0       39          State-gov    77516    Bachelors              13
# 1       50   Self-emp-not-inc    83311    Bachelors              13
# 2       38            Private   215646      HS-grad               9
# 3       53            Private   234721         11th               7
# 4       28            Private   338409    Bachelors              13
# ...    ...                ...      ...          ...             ...
# 32556   27            Private   257302   Assoc-acdm              12
# 32557   40            Private   154374      HS-grad               9
# 32558   58            Private   151910      HS-grad               9
# 32559   22            Private   201490      HS-grad               9
# 32560   52       Self-emp-inc   287927      HS-grad               9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
da=pd.concat((d,dt))

# %%
da
# Out:
#        age      workclass   fnlwgt      education   education-num  \
# 0       25        Private   226802           11th               7
# 1       38        Private    89814        HS-grad               9
# 2       28      Local-gov   336951     Assoc-acdm              12
# 3       44        Private   160323   Some-college              10
# 4       18              ?   103497   Some-college              10
# ...    ...            ...      ...            ...             ...
# 32556   27        Private   257302     Assoc-acdm              12
# 32557   40        Private   154374        HS-grad               9
# 32558   58        Private   151910        HS-grad               9
# 32559   22        Private   201490        HS-grad               9
# 32560   52   Self-emp-inc   287927        HS-grad               9
#
#             marital-status          occupation  relationship    race      sex  \
# 0            Never-married   Machine-op-inspct     Own-child   Black     Male
# ...

# %%
da[da[" marital-status"]==" Never-married"]
# Out:
#        age          workclass   fnlwgt      education   education-num  \
# 0       25            Private   226802           11th               7
# 4       18                  ?   103497   Some-college              10
# 5       34            Private   198693           10th               6
# 6       29                  ?   227026        HS-grad               9
# 8       24            Private   369667   Some-college              10
# ...    ...                ...      ...            ...             ...
# 32537   30            Private   345898        HS-grad               9
# 32548   65   Self-emp-not-inc    99359    Prof-school              15
# 32553   32            Private   116138        Masters              14
# 32555   22            Private   310152   Some-college              10
# 32559   22            Private   201490        HS-grad               9
#
#        marital-status          occupation    relationship  \
# 0       Never-married   Machine-op-inspct       Own-child
# ...

# %%
da[ "age"]
# Out:
# 0        25
# 1        38
# 2        28
# 3        44
# 4        18
#          ..
# 32556    27
# 32557    40
# 32558    58
# 32559    22
# 32560    52
# Name: age, Length: 48842, dtype: int64

# %%
import numpy as np
np.where(pd.isnull(da))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
da.values.ndim
# Out:
# 2

# %%
da.iloc[idx]
# Out:
#        age  workclass   fnlwgt      education   education-num  \
# 4       18          ?   103497   Some-college              10
# 6       29          ?   227026        HS-grad               9
# 13      58          ?   299831        HS-grad               9
# 22      72          ?   132015        7th-8th               4
# 35      65          ?   191846        HS-grad               9
# ...    ...        ...      ...            ...             ...
# 32530   35          ?   320084      Bachelors              13
# 32531   30          ?    33811      Bachelors              13
# 32539   71          ?   287372      Doctorate              16
# 32541   41          ?   202822        HS-grad               9
# 32542   72          ?   129912        HS-grad               9
#
#             marital-status  occupation    relationship                 race  \
# 4            Never-married           ?       Own-child                White
# ...

# %%
da.values[1,2]
# Out:
# 89814

# %%
mask = np.isin(da.values[:,1], " ?")  # np.in1d if np.isin is not available
idx = np.where(mask)

# %%
mask
# Out:
# array([False, False, False, ..., False, False, False])

# %%
idx
# Out:
# (array([    4,     6,    13, ..., 48820, 48822, 48823], dtype=int64),)

# %%
mask = np.isin(da.values[:,1]," ?")  # np.in1d if np.isin is not available
# idx = np.where(mask)

# %%
da.values[idx]
# Out:
# array([[18, ' ?', 103497, ..., 30, ' United-States', ' <=50K.'],
#        [29, ' ?', 227026, ..., 40, ' United-States', ' <=50K.'],
#        [58, ' ?', 299831, ..., 35, ' United-States', ' <=50K.'],
#        ...,
#        [71, ' ?', 287372, ..., 10, ' United-States', ' >50K'],
#        [41, ' ?', 202822, ..., 32, ' United-States', ' <=50K'],
#        [72, ' ?', 129912, ..., 25, ' United-States', ' <=50K']],
#       dtype=object)

# %%
idx[0].size
# Out:
# 2799

# %%
da.drop("idx")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24560\717025264.py in <module>
# ----> 1 da.drop("idx")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
# ...

# %%
idx[0]
# Out:
# array([    4,     6,    13, ..., 48820, 48822, 48823], dtype=int64)

# %%
da.drop([idx], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24560\3755779764.py in <module>
# ----> 1 da.drop([idx], axis = 1, inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
da.drop([idx[0]], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24560\2690846364.py in <module>
# ----> 1 da.drop([idx[0]], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
# ...

# %%
df = pd.DataFrame({"ones":[1,3,5],
                   "tens":[20, 40, 60]},
                  index=['barb', 'mark', 'ethan'])

# %%
df
# Out:
#        ones  tens
# barb      1    20
# mark      3    40
# ethan     5    60

# %%
df.drop([2],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24560\1845934353.py in <module>
# ----> 1 df.drop([2],axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
# ...

# %%
df.drop(['barb', 'mark'], axis='index')
# Out:
#        ones  tens
# ethan     5    60

# %%
df = pd.DataFrame({"ones":[1,3,5],
                   "tens":[20, 40, 60]})

# %%
df
# Out:
#    ones  tens
# 0     1    20
# 1     3    40
# 2     5    60
